# %% [markdown]
# # This notebook demonstrates the results of the 4 deprectated CGI modes of the Roman model.

# %%
# %pylab inline --no-import-all
matplotlib.rcParams['image.origin'] = 'lower'
matplotlib.rcParams['image.interpolation'] = 'nearest'

from importlib import reload
import os 
import webbpsf
from webbpsf import wfirst
import ipywidgets
from astropy.io import fits
import astropy.units as u
import poppy
from matplotlib.colors import LogNorm
from matplotlib.patches import Circle

webbpsf.setup_logging()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WebbPSF log messages of level INFO and above will be shown.
# WebbPSF log outputs will be directed to the screen.

# %% [markdown]
# ## Test the 660 mode.

# %%
reload(wfirst)
spc660 = wfirst.CGI(mode='CHARSPC_F660')
spc660.options['source_offset_r'] = 0 # arcsec
spc660.options['source_offset_theta'] = 0 # deg w.r.t. North

plt.figure(figsize=(9,16))
spc660.display()
# Out:
# [webbpsf] Set the following optical configuration:
# [webbpsf] camera = IFS, filter = F660, apodizer = CHARSPC, fpm = CHARSPC_F660_BOWTIE, lyotstop = LS30D88
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] Computing wavelength weights using synthetic photometry for F660...
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F660_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F660.fits.gz
# [  poppy] Added image plane: CHARSPC_F660_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=2: CGI detector
# [  poppy] Displaying plane WFIRST Entrance Pupil in row 1 of 4
# [  poppy] Displaying plane CHARSPC in row 2 of 4
# [  poppy] Displaying plane CHARSPC_F660_BOWTIE in row 3 of 4
# [  poppy] Displaying plane LS30D88 in row 4 of 4

# %%
plt.figure(figsize=[12,9])
mono_psf = spc660.calc_psf(nlambda=1, fov_arcsec=3, display=True)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] PSF calc using fov_arcsec = 3.000000, oversample = 4, number of wavelengths = 1
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F660_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F660.fits.gz
# [  poppy] Added image plane: CHARSPC_F660_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=4: CGI detector
# [  poppy] Calculating PSF with 1 wavelengths
# [  poppy]  Propagating wavelength = 6.6e-07 m
# [  poppy]  Propagating wavelength = 6.6e-07 m meters using Matrix FTs
# [  poppy]   Calculation completed in 0.620 s
# [  poppy] PSF Calculation completed.
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4

# %% [markdown]
# ## Test the 770 mode.

# %%
reload(wfirst)
spc770 = wfirst.CGI(mode='CHARSPC_F770')
spc770.options['source_offset_r'] = 0 # arcsec
spc770.options['source_offset_theta'] = 0 # deg w.r.t. North

plt.figure(figsize=(9,16))
spc770.display()
# Out:
# [webbpsf] Set the following optical configuration:
# [webbpsf] camera = IFS, filter = F770, apodizer = CHARSPC, fpm = CHARSPC_F770_BOWTIE, lyotstop = LS30D88
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] Computing wavelength weights using synthetic photometry for F770...
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F770_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F770.fits.gz
# [  poppy] Added image plane: CHARSPC_F770_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=2: CGI detector
# [  poppy] Displaying plane WFIRST Entrance Pupil in row 1 of 4
# [  poppy] Displaying plane CHARSPC in row 2 of 4
# [  poppy] Displaying plane CHARSPC_F770_BOWTIE in row 3 of 4
# [  poppy] Displaying plane LS30D88 in row 4 of 4

# %%
plt.figure(figsize=[12,9])
mono_psf = spc770.calc_psf(nlambda=1, fov_arcsec=3, display=True)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] PSF calc using fov_arcsec = 3.000000, oversample = 4, number of wavelengths = 1
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F770_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F770.fits.gz
# [  poppy] Added image plane: CHARSPC_F770_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=4: CGI detector
# [  poppy] Calculating PSF with 1 wavelengths
# [  poppy]  Propagating wavelength = 7.7e-07 m
# [  poppy]  Propagating wavelength = 7.7e-07 m meters using Matrix FTs
# [  poppy]   Calculation completed in 0.687 s
# [  poppy] PSF Calculation completed.
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4

# %% [markdown]
# ## Test the 890 mode.

# %%
reload(wfirst)
spc890 = wfirst.CGI(mode='CHARSPC_F890')
spc890.options['source_offset_r'] = 0 # arcsec
spc890.options['source_offset_theta'] = 0 # deg w.r.t. North

plt.figure(figsize=(9,16))
spc890.display()
# Out:
# [webbpsf] Set the following optical configuration:
# [webbpsf] camera = IFS, filter = F890, apodizer = CHARSPC, fpm = CHARSPC_F890_BOWTIE, lyotstop = LS30D88
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] Computing wavelength weights using synthetic photometry for F890...
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F890_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F890.fits.gz
# [  poppy] Added image plane: CHARSPC_F890_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=2: CGI detector
# [  poppy] Displaying plane WFIRST Entrance Pupil in row 1 of 4
# [  poppy] Displaying plane CHARSPC in row 2 of 4
# [  poppy] Displaying plane CHARSPC_F890_BOWTIE in row 3 of 4
# [  poppy] Displaying plane LS30D88 in row 4 of 4

# %%
plt.figure(figsize=[12,9])
mono_psf = spc890.calc_psf(nlambda=1, fov_arcsec=3, display=True)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] PSF calc using fov_arcsec = 3.000000, oversample = 4, number of wavelengths = 1
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] CHARSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: CHARSPC
# [  poppy] CHARSPC_F890_BOWTIE: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/CHARSPC_FPM_25WA90_2x65deg_-_FP1res4_evensamp_D072_F890.fits.gz
# [  poppy] Added image plane: CHARSPC_F890_BOWTIE
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=4: CGI detector
# [  poppy] Calculating PSF with 1 wavelengths
# [  poppy]  Propagating wavelength = 8.9e-07 m
# [  poppy]  Propagating wavelength = 8.9e-07 m meters using Matrix FTs
# [  poppy]   Calculation completed in 0.588 s
# [  poppy] PSF Calculation completed.
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4

# %% [markdown]
# ## Test the 721 mode.

# %%
reload(wfirst)
spc721 = wfirst.CGI(mode='DISKSPC_F721')
spc721.options['source_offset_r'] = 0 # arcsec
spc721.options['source_offset_theta'] = 0 # deg w.r.t. North

plt.figure(figsize=(9,16))
spc721.display()
# Out:
# [webbpsf] Set the following optical configuration:
# [webbpsf] camera = IMAGER, filter = F721, apodizer = DISKSPC, fpm = DISKSPC_F721_ANNULUS, lyotstop = LS30D88
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] Computing wavelength weights using synthetic photometry for F721...
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] DISKSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: DISKSPC
# [  poppy] DISKSPC_F721_ANNULUS: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_FPM_65WA200_360deg_-_FP1res3_evensamp_D120_F721.fits.gz
# [  poppy] Added image plane: DISKSPC_F721_ANNULUS
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=2: CGI detector
# [  poppy] Displaying plane WFIRST Entrance Pupil in row 1 of 4
# [  poppy] Displaying plane DISKSPC in row 2 of 4
# [  poppy] Displaying plane DISKSPC_F721_ANNULUS in row 3 of 4
# [  poppy] Displaying plane LS30D88 in row 4 of 4

# %%
lamc = 721e-9*u.m
D = 2.3631*u.m
lamD825 = lamc/D
as_per_lamD = lamc * 360.0 * 3600.0 / (2 * np.pi * D)    # as per lambda0/D
fov_as = 40*as_per_lamD.value

plt.figure(figsize=[12,9])
monopsf_onax = spc721.calc_psf(nlambda=1, fov_arcsec=fov_as, display=True)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] PSF calc using fov_arcsec = 2.517319, oversample = 4, number of wavelengths = 1
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] DISKSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: DISKSPC
# [  poppy] DISKSPC_F721_ANNULUS: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_FPM_65WA200_360deg_-_FP1res3_evensamp_D120_F721.fits.gz
# [  poppy] Added image plane: DISKSPC_F721_ANNULUS
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=4: CGI detector
# [  poppy] Calculating PSF with 1 wavelengths
# [  poppy]  Propagating wavelength = 7.21e-07 m
# [  poppy]  Propagating wavelength = 7.21e-07 m meters using Matrix FTs
# [  poppy]   Calculation completed in 0.764 s
# [  poppy] PSF Calculation completed.
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4

# %% [markdown]
# ## Calculate off-axis PSF.

# %%
spc721.options['source_offset_r'] = 0.6 #10*as_per_lamD.value # arcsec
spc721.options['source_offset_theta'] = -45. # deg w.r.t. North

plt.figure(figsize=[12,9])
monopsf_offax = spc721.calc_psf(nlambda=1, fov_arcsec=fov_as, display=True)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] PSF calc using fov_arcsec = 2.517319, oversample = 4, number of wavelengths = 1
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: WFIRST+CGI
# [  poppy] WFIRST Entrance Pupil: Loaded amplitude transmission from /groups/douglase/webbpsf-data/AFTA_CGI_C5_Pupil_onax_256px_flip.fits
# [  poppy] Added pupil plane: WFIRST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] DISKSPC: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_SP_256pix.fits.gz
# [  poppy] Added pupil plane: DISKSPC
# [  poppy] DISKSPC_F721_ANNULUS: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/DISKSPC_FPM_65WA200_360deg_-_FP1res3_evensamp_D120_F721.fits.gz
# [  poppy] Added image plane: DISKSPC_F721_ANNULUS
# [  poppy] LS30D88: Loaded amplitude transmission from /groups/douglase/webbpsf-data/CGI/optics/deprecated/SPC_LS_30D88_256pix.fits.gz
# [  poppy] Added pupil plane: LS30D88
# [  poppy] Initialized OpticalSystem: unnamed system
# [  poppy] Added detector with pixelscale=0.025 and oversampling=4: CGI detector
# [  poppy] Calculating PSF with 1 wavelengths
# [  poppy]  Propagating wavelength = 7.21e-07 m
# [  poppy]  Propagating wavelength = 7.21e-07 m meters using Matrix FTs
# [  poppy]   Calculation completed in 0.622 s
# [  poppy] PSF Calculation completed.
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4

# %% [markdown]
# ## Display both PSFs side-by-side.

# %%
fig, ax  = plt.subplots( nrows=1, ncols=2, figsize=(12,6), dpi=150)

exmax = fov_as/2
extent = [-exmax,exmax,-exmax,exmax]

im = ax[0].imshow(monopsf_onax[0].data, norm=LogNorm(), cmap=plt.get_cmap('gist_heat'), extent=extent)
circ_in = Circle((0,0),2.6,edgecolor='cyan', facecolor='none', linewidth=2)
circ_out = Circle((0,0),9,edgecolor='cyan', facecolor='none', linewidth=2)
ax[0].add_patch(circ_in)
ax[0].add_patch(circ_out)
ax[0].set_title('Speckles with Wavefront Maps\n and No Aberrations')
fig.colorbar(im, ax=ax[0], shrink=1) 

im = ax[1].imshow(monopsf_offax[0].data, norm=LogNorm(), cmap=plt.get_cmap('gist_heat'), extent=extent)
circ_in = Circle((0,0),2.6,edgecolor='cyan', facecolor='none', linewidth=2)
circ_out = Circle((0,0),9,edgecolor='cyan', facecolor='none', linewidth=2)
ax[1].add_patch(circ_in)
ax[1].add_patch(circ_out)
ax[1].set_title('Speckles with Wavefront Maps\n and No Aberrations')
fig.colorbar(im, ax=ax[1], shrink=1)

# %%
# Form a simple bright companion scene by summing the on-axis and off-axis PSF, the latter scaled by 1E-7.
offax_peak = monopsf_offax[0].data.max()
comb_img = (monopsf_onax[0].data + monopsf_offax[0].data*1e-7)/offax_peak # Contrast units
comb_hdu = fits.PrimaryHDU(comb_img, header=monopsf_onax[0].header)
comb_hdulist = fits.HDUList([comb_hdu])

webbpsf.display_psf(comb_hdulist,vmin=1e-9, vmax=3e-8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     116     try:
# --> 117         num = operator.index(num)
#     118     except TypeError:
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b82e54cc0df5> in <module>
#       5 comb_hdulist = fits.HDUList([comb_hdu])
#       6
# ----> 7 webbpsf.display_psf(comb_hdulist,vmin=1e-9, vmax=3e-8)
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/poppy/utils.py in display_psf(HDUlist_or_filename, ext, vmin, vmax, scale, cmap, title, imagecrop, adjust_for_oversampling, normalize, crosshairs, markcentroid, colorbar, colorbar_orientation, pixelscale, ax, return_ax, interpolation, cube_slice)
#     256             )
#     257         if scale.lower() == 'log':
# --> 258             ticks = np.logspace(np.log10(vmin), np.log10(vmax), np.log10(vmax / vmin) + 1)
#     259             if colorbar_orientation == 'horizontal' and vmax == 1e-1 and vmin == 1e-8:
#     260                 ticks = [1e-8, 1e-6, 1e-4, 1e-2, 1e-1]  # looks better
#
# <__array_function__ internals> in logspace(*args, **kwargs)
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/numpy/core/function_base.py in logspace(start, stop, num, endpoint, base, dtype, axis)
#     270
#     271     """
# --> 272     y = linspace(start, stop, num=num, endpoint=endpoint, axis=axis)
#     273     if dtype is None:
#     274         return _nx.power(base, y)
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     119         raise TypeError(
#     120             "object of type {} cannot be safely interpreted as an integer."
# --> 121                 .format(type(num)))
#     122
#     123     if num < 0:
#
# TypeError: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
